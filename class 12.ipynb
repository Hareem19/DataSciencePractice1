# %%
import pandas as pd

# %%
car_data=pd.read_csv(r"C:\Users\abc\Desktop\Bootcamp practice\car_data.csv")

# %%
car_data
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
car_data.dropna(inplace=True)

# %%
car_data.drop_duplicates(inplace=True)

# %%
car_data
# Out:
#                                        name   company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# ..                                      ...       ...   ...            ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011       2,70,000
# 885               Tata Indica V2 DLE BS III      Tata  2009       1,10,000
# 886                    Toyota Corolla Altis    Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel      Tata  2018       2,60,000
# 889                      Mahindra Quanto C8  Mahindra  2013       3,90,000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# ...

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 745 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        745 non-null    object
#  1   company     745 non-null    object
#  2   year        745 non-null    object
#  3   Price       745 non-null    object
#  4   kms_driven  745 non-null    object
#  5   fuel_type   745 non-null    object
# dtypes: object(6)
# memory usage: 40.7+ KB

# %%
car_data.isna().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# dtype: int64

# %%
car_data.isnull().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# dtype: int64

# %%
# car_data=car_data.dropna

# %%
# car_data

# %%
car_data.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
car_data.sample(10)
# Out:
#                                  name     company  year      Price  \
# 734        Toyota Fortuner 3.0 4x4 MT      Toyota  2013  14,99,000
# 106  Ford EcoSport Titanium 1.5L TDCi        Ford  2014   5,50,000
# 846            Maruti Suzuki Alto 800      Maruti  2016   2,50,000
# 683           Tata Sumo Gold LX BS IV        Tata  2014   2,75,000
# 150                 Hyundai Elite i20     Hyundai  2018   5,99,999
# 836          Mahindra KUV100 K8 6 STR    Mahindra  2019   5,60,000
# 849    Volkswagen Polo Highline1.2L P  Volkswagen  2017   5,25,000
# 95           Maruti Suzuki A Star Lxi      Maruti  2011   1,89,500
# 873               Maruti Suzuki Dzire      Maruti  2016   3,25,000
# 750        Maruti Suzuki Alto 800 Lxi      Maruti  2015   2,15,000
#
#        kms_driven fuel_type
# 734    97,000 kms    Diesel
# 106    44,000 kms    Diesel
# 846     2,450 kms    Petrol
# 683  1,16,000 kms    Diesel
# 150    21,000 kms    Petrol
# 836     2,875 kms    Petrol
# ...

# %%
car_data.name.unique()
# Out:
# array(['Hyundai Santro Xing XO eRLX Euro III', 'Mahindra Jeep CL550 MDI',
#        'Maruti Suzuki Alto 800 Vxi',
#        'Hyundai Grand i10 Magna 1.2 Kappa VTVT',
#        'Ford EcoSport Titanium 1.5L TDCi', 'Ford Figo', 'Hyundai Eon',
#        'Ford EcoSport Ambiente 1.5L TDCi',
#        'Maruti Suzuki Alto K10 VXi AMT', 'Skoda Fabia Classic 1.2 MPI',
#        'Maruti Suzuki Stingray VXi', 'Hyundai Elite i20 Magna 1.2',
#        'Mahindra Scorpio SLE BS IV', 'Audi A8', 'Audi Q7',
#        'Mahindra Scorpio S10', 'Maruti Suzuki Alto 800',
#        'Hyundai i20 Sportz 1.2', 'Maruti Suzuki Alto 800 Lx',
#        'Maruti Suzuki Vitara Brezza ZDi', 'Maruti Suzuki Alto LX',
#        'Mahindra Bolero DI', 'Maruti Suzuki Swift Dzire ZDi',
#        'Mahindra Scorpio S10 4WD', 'Maruti Suzuki Swift Vdi BSIII',
#        'Maruti Suzuki Wagon R VXi BS III',
#        'Maruti Suzuki Wagon R VXi Minor',
#        'Toyota Innova 2.0 G 8 STR BS IV', 'Renault Lodgy 85 PS RXL',
# ...

# %%
car_data
# Out:
#                                        name   company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# ..                                      ...       ...   ...            ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011       2,70,000
# 885               Tata Indica V2 DLE BS III      Tata  2009       1,10,000
# 886                    Toyota Corolla Altis    Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel      Tata  2018       2,60,000
# 889                      Mahindra Quanto C8  Mahindra  2013       3,90,000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# ...

# %%
car_data.duplicated().sum()
# Out:
# 0

# %%
# car_data.dropna(inplace=True)

# %%
# car_data.drop_duplicates(inplace=True)

# %%
car_data
# Out:
#                                        name   company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# ..                                      ...       ...   ...            ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011       2,70,000
# 885               Tata Indica V2 DLE BS III      Tata  2009       1,10,000
# 886                    Toyota Corolla Altis    Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel      Tata  2018       2,60,000
# 889                      Mahindra Quanto C8  Mahindra  2013       3,90,000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# ...

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 745 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        745 non-null    object
#  1   company     745 non-null    object
#  2   year        745 non-null    object
#  3   Price       745 non-null    object
#  4   kms_driven  745 non-null    object
#  5   fuel_type   745 non-null    object
# dtypes: object(6)
# memory usage: 40.7+ KB

# %%
car_data.name
# Out:
# 0        Hyundai Santro Xing XO eRLX Euro III
# 1                     Mahindra Jeep CL550 MDI
# 2                  Maruti Suzuki Alto 800 Vxi
# 3      Hyundai Grand i10 Magna 1.2 Kappa VTVT
# 4            Ford EcoSport Titanium 1.5L TDCi
#                         ...
# 883                Maruti Suzuki Ritz VXI ABS
# 885                 Tata Indica V2 DLE BS III
# 886                      Toyota Corolla Altis
# 888                       Tata Zest XM Diesel
# 889                        Mahindra Quanto C8
# Name: name, Length: 745, dtype: object

# %%
car_data.name=car_data.name.str.split().str[:3].str.join(' ')

# %%
car_data.company
# Out:
# 0       Hyundai
# 1      Mahindra
# 2        Maruti
# 3       Hyundai
# 4          Ford
#          ...
# 883      Maruti
# 885        Tata
# 886      Toyota
# 888        Tata
# 889    Mahindra
# Name: company, Length: 745, dtype: object

# %%
car_data.company.unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Maruti', 'Ford', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat', 'Force',
#        'Mercedes', 'Land', 'Jaguar', 'Jeep', 'Volvo'], dtype=object)

# %%
car_data.year
# Out:
# 0      2007
# 1      2006
# 2      2018
# 3      2014
# 4      2014
#        ...
# 883    2011
# 885    2009
# 886    2009
# 888    2018
# 889    2013
# Name: year, Length: 745, dtype: object

# %%
car_data.year.unique
# Out:
# <bound method Series.unique of 0      2007
# 1      2006
# 2      2018
# 3      2014
# 4      2014
#        ...
# 883    2011
# 885    2009
# 886    2009
# 888    2018
# 889    2013
# Name: year, Length: 745, dtype: object>

# %%
car_data.Price
# Out:
# 0             80,000
# 1           4,25,000
# 2      Ask For Price
# 3           3,25,000
# 4           5,75,000
#            ...
# 883         2,70,000
# 885         1,10,000
# 886         3,00,000
# 888         2,60,000
# 889         3,90,000
# Name: Price, Length: 745, dtype: object

# %%
car_data.Price.value_counts()
# Out:
# Ask For Price    21
# 2,50,000         13
# 1,30,000         11
# 3,50,000         11
# 4,00,000         10
#                  ..
# 7,70,000          1
# 3,35,000          1
# 6,35,000          1
# 65,000            1
# 5,00,001          1
# Name: Price, Length: 273, dtype: int64

# %%
car_data.kms_driven
# Out:
# 0        45,000 kms
# 1            40 kms
# 2        22,000 kms
# 3        28,000 kms
# 4        36,000 kms
#            ...
# 883      50,000 kms
# 885      30,000 kms
# 886    1,32,000 kms
# 888      27,000 kms
# 889      40,000 kms
# Name: kms_driven, Length: 745, dtype: object

# %%
car_data.kms_driven.unique()
# Out:
# array(['45,000 kms', '40 kms', '22,000 kms', '28,000 kms', '36,000 kms',
#        '59,000 kms', '41,000 kms', '25,000 kms', '24,530 kms',
#        '60,000 kms', '30,000 kms', '32,000 kms', '48,660 kms',
#        '4,000 kms', '16,934 kms', '43,000 kms', '35,550 kms',
#        '39,522 kms', '39,000 kms', '55,000 kms', '72,000 kms',
#        '15,975 kms', '70,000 kms', '23,452 kms', '35,522 kms',
#        '48,508 kms', '15,487 kms', '82,000 kms', '20,000 kms',
#        '68,000 kms', '38,000 kms', '27,000 kms', '33,000 kms',
#        '46,000 kms', '16,000 kms', '47,000 kms', '35,000 kms',
#        '30,874 kms', '15,000 kms', '29,685 kms', '1,30,000 kms',
#        '19,000 kms', '54,000 kms', '13,000 kms', '38,200 kms',
#        '50,000 kms', '13,500 kms', '3,600 kms', '45,863 kms',
#        '60,500 kms', '12,500 kms', '18,000 kms', '13,349 kms',
#        '29,000 kms', '44,000 kms', '42,000 kms', '14,000 kms',
#        '49,000 kms', '36,200 kms', '51,000 kms', '1,04,000 kms',
# ...

# %%
car_data.kms_driven=car_data.kms_driven.str.replace(",","").str.replace("kms","")

# %%
car_data
# Out:
#                        name   company  year          Price kms_driven  \
# 0       Hyundai Santro Xing   Hyundai  2007         80,000     45000
# 1       Mahindra Jeep CL550  Mahindra  2006       4,25,000        40
# 2        Maruti Suzuki Alto    Maruti  2018  Ask For Price     22000
# 3         Hyundai Grand i10   Hyundai  2014       3,25,000     28000
# 4    Ford EcoSport Titanium      Ford  2014       5,75,000     36000
# ..                      ...       ...   ...            ...        ...
# 883      Maruti Suzuki Ritz    Maruti  2011       2,70,000     50000
# 885          Tata Indica V2      Tata  2009       1,10,000     30000
# 886    Toyota Corolla Altis    Toyota  2009       3,00,000    132000
# 888            Tata Zest XM      Tata  2018       2,60,000     27000
# 889      Mahindra Quanto C8  Mahindra  2013       3,90,000     40000
#
#     fuel_type
# 0      Petrol
# 1      Diesel
# 2      Petrol
# 3      Petrol
# 4      Diesel
# ..        ...
# 883    Petrol
# ...

# %%
car_data.Price.max()
# Out:
# 'Ask For Price'

# %%
car_data.kms_driven=car_data.kms_driven.astype('float64')

# %%
car_data.kms_driven
# Out:
# 0       45000.0
# 1          40.0
# 2       22000.0
# 3       28000.0
# 4       36000.0
#          ...
# 883     50000.0
# 885     30000.0
# 886    132000.0
# 888     27000.0
# 889     40000.0
# Name: kms_driven, Length: 745, dtype: float64

# %%
car_data
# Out:
#                        name   company  year          Price  kms_driven  \
# 0       Hyundai Santro Xing   Hyundai  2007         80,000     45000.0
# 1       Mahindra Jeep CL550  Mahindra  2006       4,25,000        40.0
# 2        Maruti Suzuki Alto    Maruti  2018  Ask For Price     22000.0
# 3         Hyundai Grand i10   Hyundai  2014       3,25,000     28000.0
# 4    Ford EcoSport Titanium      Ford  2014       5,75,000     36000.0
# ..                      ...       ...   ...            ...         ...
# 883      Maruti Suzuki Ritz    Maruti  2011       2,70,000     50000.0
# 885          Tata Indica V2      Tata  2009       1,10,000     30000.0
# 886    Toyota Corolla Altis    Toyota  2009       3,00,000    132000.0
# 888            Tata Zest XM      Tata  2018       2,60,000     27000.0
# 889      Mahindra Quanto C8  Mahindra  2013       3,90,000     40000.0
#
#     fuel_type category by lamda
# 0      Petrol         expensive
# 1      Diesel         expensive
# ...

# %%
car_data['category by lamda']=car_data.Price.apply(lambda p:"expensive" if p>car_data.Price.median() else "cheap")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:760, in nanmedian(values, axis, skipna, mask)
#     759 try:
# --> 760     values = values.astype("f8")
#     761 except ValueError as err:
#     762     # e.g. "could not convert string to float: 'a'"
#
# ValueError: could not convert string to float: '80,000'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 car_data['category by lamda']=car_data.Price.apply(lambda p:"expensive" if p>car_data.Price.median() else "cheap")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
# ...

# %%
car_data
# Out:
#                        name   company  year          Price  kms_driven  \
# 0       Hyundai Santro Xing   Hyundai  2007         80,000     45000.0
# 1       Mahindra Jeep CL550  Mahindra  2006       4,25,000        40.0
# 2        Maruti Suzuki Alto    Maruti  2018  Ask For Price     22000.0
# 3         Hyundai Grand i10   Hyundai  2014       3,25,000     28000.0
# 4    Ford EcoSport Titanium      Ford  2014       5,75,000     36000.0
# ..                      ...       ...   ...            ...         ...
# 883      Maruti Suzuki Ritz    Maruti  2011       2,70,000     50000.0
# 885          Tata Indica V2      Tata  2009       1,10,000     30000.0
# 886    Toyota Corolla Altis    Toyota  2009       3,00,000    132000.0
# 888            Tata Zest XM      Tata  2018       2,60,000     27000.0
# 889      Mahindra Quanto C8  Mahindra  2013       3,90,000     40000.0
#
#     fuel_type category by lamda
# 0      Petrol         expensive
# 1      Diesel         expensive
# ...
